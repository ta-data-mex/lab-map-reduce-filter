# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
import numpy as np
import pandas as pd
from functools import reduce

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
prophet = prophet[568:]
prophet
# Out:
# ['dispense',
#  'with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields',
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  'in\nwhat',
#  'unremembered',
#  'seasons?\n\nIf',
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  'I\nlift',
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  'flame\nthat',
#  'shall',
#  'burn',
#  'therein.\n\nEmpty',
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,\n\nAnd',
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  'fill\nit',
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  'also.\n\n*****\n\nThese',
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  'much\nin',
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  '{12}he\nhimself',
#  'could',
#  'not',
#  'speak',
#  'his',
#  'deeper\nsecret.\n\n*****\n\n[Illustration:',
#  '0020]\n\nAnd',
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  'all\nthe',
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  'they\nwere',
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  'one\nvoice.\n\nAnd',
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  'forth\nand',
#  'said:\n\nGo',
#  'not',
#  'yet',
#  'away',
#  'from',
#  'us.\n\nA',
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  'our\ntwilight,',
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us\ndreams',
#  'to',
#  'dream.\n\nNo',
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  'nor\na',
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  'dearly\nbeloved.\n\nSuffer',
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  'for\nyour',
#  'face.\n\n*****\n\nAnd',
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  'said\nunto',
#  'him:\n\nLet',
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  'us\nnow,',
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  'our\nmidst',
#  'become',
#  'a',
#  'memory.\n\nYou',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  'spirit,\n{13}and',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  'light\nupon',
#  'our',
#  'faces.\n\nMuch',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless\nwas',
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  'been\nveiled.\n\nYet',
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and\nwould',
#  'stand',
#  'revealed',
#  'before',
#  'you.\n\nAnd',
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  'knows\nnot',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  'of\nseparation.\n\n*****\n\nAnd',
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  'him.\nBut',
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent\nhis',
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  'saw\nhis',
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  'breast.\n\nAnd',
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  'towards\nthe',
#  'great',
#  'square',
#  'before',
#  'the',
#  'temple.\n\nAnd',
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  'a\nwoman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she\nwas',
#  'a',
#  'seeress.\n\nAnd',
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  'exceeding\ntenderness,',
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first\nsought',
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  'had\nbeen',
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  '{14}And\nshe',
#  'hailed',
#  'him,',
#  'saying:\n\nProphet',
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  'the\nuttermost,',
#  'long',
#  'have',
#  'you',
#  'searched',
#  'the\ndistances',
#  'for',
#  'your',
#  'ship.\n\nAnd',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  'must\nneeds',
#  'go.\n\nDeep',
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  'of\nyour',
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  'place\nof',
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  'love\nwould',
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  'hold\nyou.\n\nYet',
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  'that\nyou',
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  'your\ntruth.\n\nAnd',
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  'children,\nand',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  'it\nshall',
#  'not',
#  'perish.\n\nIn',
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  'with\nour',
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  'you\nhave',
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  'the\nlaughter',
#  'of',
#  'our',
#  'sleep.\n\nNow',
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  'ourselves,\nand',
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  'shown\nyou',
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  'and\ndeath.\n\n*****\n\nAnd',
#  'he',
#  'answered,\n\nPeople',
#  'of',
#  'Orphalese,',
#  'of',
#  'what',
#  'can',
#  'I\n{15}speak',
#  'save',
#  'of',
#  'that',
#  'which',
#  'is',
#  'even',
#  'now\nmoving',
#  'within',
#  'your',
#  'souls?\n\n*****',
#  '*****\n\nThen',
#  'said',
#  'Almitra,',
#  'Speak',
#  'to',
#  'us',
#  'of\n_Love_.\n\nAnd',
#  'he',
#  'raised',
#  'his',
#  'head',
#  'and',
#  'looked',
#  'upon\nthe',
#  'people,',
#  'and',
#  'there',
#  'fell',
#  'a',
#  'stillness\nupon',
#  'them.',
#  'And',
#  'with',
#  'a',
#  'great',
#  'voice',
#  'he\nsaid:\n\nWhen',
#  'love',
#  'beckons',
#  'to',
#  'you,',
#  'follow',
#  'him,\n\nThough',
#  'his',
#  'ways',
#  'are',
#  'hard',
#  'and',
#  'steep.\n\nAnd',
#  'when',
#  'his',
#  'wings',
#  'enfold',
#  'you',
#  'yield',
#  'to\nhim,\n\nThough',
#  'the',
#  'sword',
#  'hidden',
#  'among',
#  'his\npinions',
#  'may',
#  'wound',
#  'you.\n\nAnd',
#  'when',
#  'he',
#  'speaks',
#  'to',
#  'you',
#  'believe',
#  'in\nhim,\n\nThough',
#  'his',
#  'voice',
#  'may',
#  'shatter',
#  'your',
#  'dreams\nas',
#  'the',
#  'north',
#  'wind',
#  'lays',
#  'waste',
#  'the',
#  'garden.\n\nFor',
#  'even',
#  'as',
#  'love',
#  'crowns',
#  'you',
#  'so',
#  'shall\nhe',
#  'crucify',
#  'you.',
#  'Even',
#  'as',
#  'he',
#  'is',
#  'for',
#  'your\ngrowth',
#  'so',
#  'is',
#  'he',
#  'for',
#  'your',
#  'pruning.\n\nEven',
#  'as',
#  'he',
#  'ascends',
#  'to',
#  'your',
#  'height',
#  'and\n{16}caresses',
#  'your',
#  'tenderest',
#  'branches\nthat',
#  'quiver',
#  'in',
#  'the',
#  'sun,\n\nSo',
#  'shall',
#  'he',
#  'descend',
#  'to',
#  'your',
#  'roots',
#  'and\nshake',
#  'them',
#  'in',
#  'their',
#  'clinging',
#  'to',
#  'the\nearth.\n\n*****\n\nLike',
#  'sheaves',
#  'of',
#  'corn',
#  'he',
#  'gathers',
#  'you',
#  'unto\nhimself.\n\nHe',
#  'threshes',
#  'you',
#  'to',
#  'make',
#  'you',
#  'naked.\n\nHe',
#  'sifts',
#  'you',
#  'to',
#  'free',
#  'you',
#  'from',
#  'your\nhusks.\n\nHe',
#  'grinds',
#  'you',
#  'to',
#  'whiteness.\n\nHe',
#  'kneads',
#  'you',
#  'until',
#  'you',
#  'are',
#  'pliant;\n\nAnd',
#  'then',
#  'he',
#  'assigns',
#  'you',
#  'to',
#  'his',
#  'sacred\nfire,',
#  'that',
#  'you',
#  'may',
#  'become',
#  'sacred',
#  'bread\nfor',
#  'God’s',
#  'sacred',
#  'feast.\n\n*****\n\nAll',
#  'these',
#  'things',
#  'shall',
#  'love',
#  'do',
#  'unto',
#  'you\nthat',
#  'you',
#  'may',
#  'know',
#  'the',
#  'secrets',
#  'of',
#  'your\nheart,',
#  'and',
#  'in',
#  'that',
#  'knowledge',
#  'become',
#  'a\nfragment',
#  'of',
#  'Life’s',
#  'heart.\n\nBut',
#  'if',
#  'in',
#  'your',
#  'fear',
#  'you',
#  'would',
#  'seek',
#  'only\nlove’s',
#  'peace',
#  'and',
#  'love’s',
#  'pleasure,\n\nThen',
#  'it',
#  'is',
#  'better',
#  'for',
#  'you',
#  'that',
#  'you\ncover',
#  '{17}your',
#  'nakedness',
#  'and',
#  'pass',
#  'out',
#  'of\nlove’s',
#  'threshing-floor,\n\nInto',
#  'the',
#  'seasonless',
#  'world',
#  'where',
#  'you\nshall',
#  'laugh,',
#  'but',
#  'not',
#  'all',
#  'of',
#  'your\nlaughter,',
#  'and',
#  'weep,',
#  'but',
#  'not',
#  'all',
#  'of',
#  'your\ntears.\n\n*****\n\nLove',
#  'gives',
#  'naught',
#  'but',
#  'itself',
#  'and',
#  'takes\nnaught',
#  'but',
#  'from',
#  'itself.\n\nLove',
#  'possesses',
#  'not',
#  'nor',
#  'would',
#  'it',
#  'be\npossessed;\n\nFor',
#  'love',
#  'is',
#  'sufficient',
#  'unto',
#  'love.\n\nWhen',
#  'you',
#  'love',
#  'you',
#  'should',
#  'not',
#  'say,',
#  '“God\nis',
#  'in',
#  'my',
#  'heart,”',
#  'but',
#  'rather,',
#  '“I',
#  'am',
#  'in\nthe',
#  'heart',
#  'of',
#  'God.”\n\nAnd',
#  'think',
#  'not',
#  'you',
#  'can',
#  'direct',
#  'the',
#  'course\nof',
#  'love,',
#  'for',
#  'love,',
#  'if',
#  'it',
#  'finds',
#  'you\nworthy,',
#  'directs',
#  'your',
#  'course.\n\nLove',
#  'has',
#  'no',
#  'other',
#  'desire',
#  'but',
#  'to',
#  'fulfil\nitself.\n\nBut',
#  'if',
#  'you',
#  'love',
#  'and',
#  'must',
#  'needs',
#  'have\ndesires,',
#  'let',
#  'these',
#  'be',
#  'your',
#  'desires:\n\nTo',
#  'melt',
#  'and',
#  'be',
#  'like',
#  'a',
#  'running',
#  'brook',
#  'that\nsings',
#  'its',
#  'melody',
#  'to',
#  'the',
#  'night.',
#  '{18}To\nknow',
#  'the',
#  'pain',
#  'of',
#  'too',
#  'much',
#  'tenderness.\n\nTo',
#  'be',
#  'wounded',
#  'by',
#  'your',
#  'own',
#  'understanding\nof',
#  'love;\n\nAnd',
#  'to',
#  'bleed',
#  'willingly',
#  'and',
#  'joyfully.\n\nTo',
#  'wake',
#  'at',
#  'dawn',
#  'with',
#  'a',
#  'winged',
#  'heart',
#  'and\ngive',
#  'thanks',
#  'for',
#  'another',
#  'day',
#  'of',
#  'loving;\n\nTo',
#  'rest',
#  'at',
#  'the',
#  'noon',
#  'hour',
#  'and',
#  'meditate\nlove’s',
#  'ecstacy;\n\nTo',
#  'return',
#  'home',
#  'at',
#  'eventide',
#  'with\ngratitude;\n\nAnd',
#  'then',
#  'to',
#  'sleep',
#  'with',
#  'a',
#  'prayer',
#  'for\nthe',
#  'beloved',
#  'in',
#  'your',
#  'heart',
#  'and',
#  'a',
#  'song',
#  'of\npraise',
#  'upon',
#  'your',
#  'lips.\n\n[Illustration:',
#  '0029]\n\n*****',
#  '*****\n\n{19}Then',
#  'Almitra',
#  'spoke',
#  'again',
#  'and',
#  'said,\nAnd',
#  'what',
#  'of',
#  '_Marriage_',
#  'master?\n\nAnd',
#  'he',
#  'answered',
#  'saying:\n\nYou',
#  'were',
#  'born',
#  'together,',
#  'and',
#  'together',
#  'you\nshall',
#  'be',
#  'forevermore.\n\nYou',
#  'shall',
#  'be',
#  'together',
#  'when',
#  'the',
#  'white\nwings',
#  'of',
#  'death',
#  'scatter',
#  'your',
#  'days.\n\nAye,',
#  'you',
#  'shall',
#  'be',
#  'together',
#  'even',
#  'in',
#  'the\nsilent',
#  'memory',
#  'of',
#  'God.\n\nBut',
#  'let',
#  'there',
#  'be',
#  'spaces',
#  'in',
#  'your\ntogetherness,\n\nAnd',
#  'let',
#  'the',
#  'winds',
#  'of',
#  'the',
#  'heavens',
#  'dance\nbetween',
#  'you.\n\n*****\n\nLove',
#  'one',
#  'another,',
#  'but',
#  'make',
#  'not',
#  'a',
#  'bond',
#  'of\nlove:\n\nLet',
#  'it',
#  'rather',
#  'be',
#  'a',
#  'moving',
#  'sea',
#  'between\nthe',
#  'shores',
#  'of',
#  'your',
#  'souls.\n\nFill',
#  'each',
#  'other’s',
#  'cup',
#  'but',
#  'drink',
#  'not',
#  'from\none',
#  'cup.\n\nGive',
#  'one',
#  'another',
#  'of',
#  'your',
#  'bread',
#  'but',
#  'eat\nnot',
#  'from',
#  'the',
#  'same',
#  'loaf.',
#  '{20}Sing',
#  'and\ndance',
#  'together',
#  'and',
#  'be',
#  'joyous,',
#  'but',
#  'let\neach',
#  'one',
#  'of',
#  'you',
#  'be',
#  'alone,\n\nEven',
#  'as',
#  'the',
#  'strings',
#  'of',
#  'a',
#  'lute',
#  'are',
#  'alone\nthough',
#  'they',
#  'quiver',
#  'with',
#  'the',
#  'same',
#  'music.\n\n*****\n\nGive',
#  'your',
#  'hearts,',
#  'but',
#  'not',
#  'into',
#  'each\nother’s',
#  'keeping.\n\nFor',
#  'only',
#  'the',
#  'hand',
#  'of',
#  'Life',
#  'can',
#  'contain\nyour',
#  'hearts.\n\nAnd',
#  'stand',
#  'together',
#  'yet',
#  'not',
#  'too',
#  'near\ntogether:\n\nFor',
#  'the',
#  'pillars',
#  'of',
#  'the',
#  'temple',
#  'stand\napart,\n\nAnd',
#  'the',
#  'oak',
#  'tree',
#  'and',
#  'the',
#  'cypress',
#  'grow\nnot',
#  'in',
#  'each',
#  'other’s',
#  'shadow.\n\n[Illustration:',
#  '0032]\n\n*****',
#  '*****\n\n{21}And',
#  'a',
#  'woman',
#  'who',
#  'held',
#  'a',
#  'babe\nagainst',
#  ...]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:
prophet[1:11]
# Out:
# ['with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    import re
    # Your code here:
    return re.sub(r'\{\d+\}', '', x)
reference('the{7}')
# Out:
# 'the'

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
# Your code here:
prophet_reference = list(map(reference,prophet))
prophet_reference
# Out:
# ['dispense',
#  'with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields',
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  'in\nwhat',
#  'unremembered',
#  'seasons?\n\nIf',
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  'I\nlift',
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  'flame\nthat',
#  'shall',
#  'burn',
#  'therein.\n\nEmpty',
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,\n\nAnd',
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  'fill\nit',
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  'also.\n\n*****\n\nThese',
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  'much\nin',
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  'he\nhimself',
#  'could',
#  'not',
#  'speak',
#  'his',
#  'deeper\nsecret.\n\n*****\n\n[Illustration:',
#  '0020]\n\nAnd',
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  'all\nthe',
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  'they\nwere',
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  'one\nvoice.\n\nAnd',
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  'forth\nand',
#  'said:\n\nGo',
#  'not',
#  'yet',
#  'away',
#  'from',
#  'us.\n\nA',
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  'our\ntwilight,',
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us\ndreams',
#  'to',
#  'dream.\n\nNo',
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  'nor\na',
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  'dearly\nbeloved.\n\nSuffer',
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  'for\nyour',
#  'face.\n\n*****\n\nAnd',
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  'said\nunto',
#  'him:\n\nLet',
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  'us\nnow,',
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  'our\nmidst',
#  'become',
#  'a',
#  'memory.\n\nYou',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  'spirit,\nand',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  'light\nupon',
#  'our',
#  'faces.\n\nMuch',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless\nwas',
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  'been\nveiled.\n\nYet',
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and\nwould',
#  'stand',
#  'revealed',
#  'before',
#  'you.\n\nAnd',
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  'knows\nnot',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  'of\nseparation.\n\n*****\n\nAnd',
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  'him.\nBut',
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent\nhis',
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  'saw\nhis',
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  'breast.\n\nAnd',
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  'towards\nthe',
#  'great',
#  'square',
#  'before',
#  'the',
#  'temple.\n\nAnd',
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  'a\nwoman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she\nwas',
#  'a',
#  'seeress.\n\nAnd',
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  'exceeding\ntenderness,',
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first\nsought',
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  'had\nbeen',
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  'And\nshe',
#  'hailed',
#  'him,',
#  'saying:\n\nProphet',
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  'the\nuttermost,',
#  'long',
#  'have',
#  'you',
#  'searched',
#  'the\ndistances',
#  'for',
#  'your',
#  'ship.\n\nAnd',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  'must\nneeds',
#  'go.\n\nDeep',
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  'of\nyour',
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  'place\nof',
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  'love\nwould',
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  'hold\nyou.\n\nYet',
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  'that\nyou',
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  'your\ntruth.\n\nAnd',
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  'children,\nand',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  'it\nshall',
#  'not',
#  'perish.\n\nIn',
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  'with\nour',
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  'you\nhave',
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  'the\nlaughter',
#  'of',
#  'our',
#  'sleep.\n\nNow',
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  'ourselves,\nand',
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  'shown\nyou',
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  'and\ndeath.\n\n*****\n\nAnd',
#  'he',
#  'answered,\n\nPeople',
#  'of',
#  'Orphalese,',
#  'of',
#  'what',
#  'can',
#  'I\nspeak',
#  'save',
#  'of',
#  'that',
#  'which',
#  'is',
#  'even',
#  'now\nmoving',
#  'within',
#  'your',
#  'souls?\n\n*****',
#  '*****\n\nThen',
#  'said',
#  'Almitra,',
#  'Speak',
#  'to',
#  'us',
#  'of\n_Love_.\n\nAnd',
#  'he',
#  'raised',
#  'his',
#  'head',
#  'and',
#  'looked',
#  'upon\nthe',
#  'people,',
#  'and',
#  'there',
#  'fell',
#  'a',
#  'stillness\nupon',
#  'them.',
#  'And',
#  'with',
#  'a',
#  'great',
#  'voice',
#  'he\nsaid:\n\nWhen',
#  'love',
#  'beckons',
#  'to',
#  'you,',
#  'follow',
#  'him,\n\nThough',
#  'his',
#  'ways',
#  'are',
#  'hard',
#  'and',
#  'steep.\n\nAnd',
#  'when',
#  'his',
#  'wings',
#  'enfold',
#  'you',
#  'yield',
#  'to\nhim,\n\nThough',
#  'the',
#  'sword',
#  'hidden',
#  'among',
#  'his\npinions',
#  'may',
#  'wound',
#  'you.\n\nAnd',
#  'when',
#  'he',
#  'speaks',
#  'to',
#  'you',
#  'believe',
#  'in\nhim,\n\nThough',
#  'his',
#  'voice',
#  'may',
#  'shatter',
#  'your',
#  'dreams\nas',
#  'the',
#  'north',
#  'wind',
#  'lays',
#  'waste',
#  'the',
#  'garden.\n\nFor',
#  'even',
#  'as',
#  'love',
#  'crowns',
#  'you',
#  'so',
#  'shall\nhe',
#  'crucify',
#  'you.',
#  'Even',
#  'as',
#  'he',
#  'is',
#  'for',
#  'your\ngrowth',
#  'so',
#  'is',
#  'he',
#  'for',
#  'your',
#  'pruning.\n\nEven',
#  'as',
#  'he',
#  'ascends',
#  'to',
#  'your',
#  'height',
#  'and\ncaresses',
#  'your',
#  'tenderest',
#  'branches\nthat',
#  'quiver',
#  'in',
#  'the',
#  'sun,\n\nSo',
#  'shall',
#  'he',
#  'descend',
#  'to',
#  'your',
#  'roots',
#  'and\nshake',
#  'them',
#  'in',
#  'their',
#  'clinging',
#  'to',
#  'the\nearth.\n\n*****\n\nLike',
#  'sheaves',
#  'of',
#  'corn',
#  'he',
#  'gathers',
#  'you',
#  'unto\nhimself.\n\nHe',
#  'threshes',
#  'you',
#  'to',
#  'make',
#  'you',
#  'naked.\n\nHe',
#  'sifts',
#  'you',
#  'to',
#  'free',
#  'you',
#  'from',
#  'your\nhusks.\n\nHe',
#  'grinds',
#  'you',
#  'to',
#  'whiteness.\n\nHe',
#  'kneads',
#  'you',
#  'until',
#  'you',
#  'are',
#  'pliant;\n\nAnd',
#  'then',
#  'he',
#  'assigns',
#  'you',
#  'to',
#  'his',
#  'sacred\nfire,',
#  'that',
#  'you',
#  'may',
#  'become',
#  'sacred',
#  'bread\nfor',
#  'God’s',
#  'sacred',
#  'feast.\n\n*****\n\nAll',
#  'these',
#  'things',
#  'shall',
#  'love',
#  'do',
#  'unto',
#  'you\nthat',
#  'you',
#  'may',
#  'know',
#  'the',
#  'secrets',
#  'of',
#  'your\nheart,',
#  'and',
#  'in',
#  'that',
#  'knowledge',
#  'become',
#  'a\nfragment',
#  'of',
#  'Life’s',
#  'heart.\n\nBut',
#  'if',
#  'in',
#  'your',
#  'fear',
#  'you',
#  'would',
#  'seek',
#  'only\nlove’s',
#  'peace',
#  'and',
#  'love’s',
#  'pleasure,\n\nThen',
#  'it',
#  'is',
#  'better',
#  'for',
#  'you',
#  'that',
#  'you\ncover',
#  'your',
#  'nakedness',
#  'and',
#  'pass',
#  'out',
#  'of\nlove’s',
#  'threshing-floor,\n\nInto',
#  'the',
#  'seasonless',
#  'world',
#  'where',
#  'you\nshall',
#  'laugh,',
#  'but',
#  'not',
#  'all',
#  'of',
#  'your\nlaughter,',
#  'and',
#  'weep,',
#  'but',
#  'not',
#  'all',
#  'of',
#  'your\ntears.\n\n*****\n\nLove',
#  'gives',
#  'naught',
#  'but',
#  'itself',
#  'and',
#  'takes\nnaught',
#  'but',
#  'from',
#  'itself.\n\nLove',
#  'possesses',
#  'not',
#  'nor',
#  'would',
#  'it',
#  'be\npossessed;\n\nFor',
#  'love',
#  'is',
#  'sufficient',
#  'unto',
#  'love.\n\nWhen',
#  'you',
#  'love',
#  'you',
#  'should',
#  'not',
#  'say,',
#  '“God\nis',
#  'in',
#  'my',
#  'heart,”',
#  'but',
#  'rather,',
#  '“I',
#  'am',
#  'in\nthe',
#  'heart',
#  'of',
#  'God.”\n\nAnd',
#  'think',
#  'not',
#  'you',
#  'can',
#  'direct',
#  'the',
#  'course\nof',
#  'love,',
#  'for',
#  'love,',
#  'if',
#  'it',
#  'finds',
#  'you\nworthy,',
#  'directs',
#  'your',
#  'course.\n\nLove',
#  'has',
#  'no',
#  'other',
#  'desire',
#  'but',
#  'to',
#  'fulfil\nitself.\n\nBut',
#  'if',
#  'you',
#  'love',
#  'and',
#  'must',
#  'needs',
#  'have\ndesires,',
#  'let',
#  'these',
#  'be',
#  'your',
#  'desires:\n\nTo',
#  'melt',
#  'and',
#  'be',
#  'like',
#  'a',
#  'running',
#  'brook',
#  'that\nsings',
#  'its',
#  'melody',
#  'to',
#  'the',
#  'night.',
#  'To\nknow',
#  'the',
#  'pain',
#  'of',
#  'too',
#  'much',
#  'tenderness.\n\nTo',
#  'be',
#  'wounded',
#  'by',
#  'your',
#  'own',
#  'understanding\nof',
#  'love;\n\nAnd',
#  'to',
#  'bleed',
#  'willingly',
#  'and',
#  'joyfully.\n\nTo',
#  'wake',
#  'at',
#  'dawn',
#  'with',
#  'a',
#  'winged',
#  'heart',
#  'and\ngive',
#  'thanks',
#  'for',
#  'another',
#  'day',
#  'of',
#  'loving;\n\nTo',
#  'rest',
#  'at',
#  'the',
#  'noon',
#  'hour',
#  'and',
#  'meditate\nlove’s',
#  'ecstacy;\n\nTo',
#  'return',
#  'home',
#  'at',
#  'eventide',
#  'with\ngratitude;\n\nAnd',
#  'then',
#  'to',
#  'sleep',
#  'with',
#  'a',
#  'prayer',
#  'for\nthe',
#  'beloved',
#  'in',
#  'your',
#  'heart',
#  'and',
#  'a',
#  'song',
#  'of\npraise',
#  'upon',
#  'your',
#  'lips.\n\n[Illustration:',
#  '0029]\n\n*****',
#  '*****\n\nThen',
#  'Almitra',
#  'spoke',
#  'again',
#  'and',
#  'said,\nAnd',
#  'what',
#  'of',
#  '_Marriage_',
#  'master?\n\nAnd',
#  'he',
#  'answered',
#  'saying:\n\nYou',
#  'were',
#  'born',
#  'together,',
#  'and',
#  'together',
#  'you\nshall',
#  'be',
#  'forevermore.\n\nYou',
#  'shall',
#  'be',
#  'together',
#  'when',
#  'the',
#  'white\nwings',
#  'of',
#  'death',
#  'scatter',
#  'your',
#  'days.\n\nAye,',
#  'you',
#  'shall',
#  'be',
#  'together',
#  'even',
#  'in',
#  'the\nsilent',
#  'memory',
#  'of',
#  'God.\n\nBut',
#  'let',
#  'there',
#  'be',
#  'spaces',
#  'in',
#  'your\ntogetherness,\n\nAnd',
#  'let',
#  'the',
#  'winds',
#  'of',
#  'the',
#  'heavens',
#  'dance\nbetween',
#  'you.\n\n*****\n\nLove',
#  'one',
#  'another,',
#  'but',
#  'make',
#  'not',
#  'a',
#  'bond',
#  'of\nlove:\n\nLet',
#  'it',
#  'rather',
#  'be',
#  'a',
#  'moving',
#  'sea',
#  'between\nthe',
#  'shores',
#  'of',
#  'your',
#  'souls.\n\nFill',
#  'each',
#  'other’s',
#  'cup',
#  'but',
#  'drink',
#  'not',
#  'from\none',
#  'cup.\n\nGive',
#  'one',
#  'another',
#  'of',
#  'your',
#  'bread',
#  'but',
#  'eat\nnot',
#  'from',
#  'the',
#  'same',
#  'loaf.',
#  'Sing',
#  'and\ndance',
#  'together',
#  'and',
#  'be',
#  'joyous,',
#  'but',
#  'let\neach',
#  'one',
#  'of',
#  'you',
#  'be',
#  'alone,\n\nEven',
#  'as',
#  'the',
#  'strings',
#  'of',
#  'a',
#  'lute',
#  'are',
#  'alone\nthough',
#  'they',
#  'quiver',
#  'with',
#  'the',
#  'same',
#  'music.\n\n*****\n\nGive',
#  'your',
#  'hearts,',
#  'but',
#  'not',
#  'into',
#  'each\nother’s',
#  'keeping.\n\nFor',
#  'only',
#  'the',
#  'hand',
#  'of',
#  'Life',
#  'can',
#  'contain\nyour',
#  'hearts.\n\nAnd',
#  'stand',
#  'together',
#  'yet',
#  'not',
#  'too',
#  'near\ntogether:\n\nFor',
#  'the',
#  'pillars',
#  'of',
#  'the',
#  'temple',
#  'stand\napart,\n\nAnd',
#  'the',
#  'oak',
#  'tree',
#  'and',
#  'the',
#  'cypress',
#  'grow\nnot',
#  'in',
#  'each',
#  'other’s',
#  'shadow.\n\n[Illustration:',
#  '0032]\n\n*****',
#  '*****\n\nAnd',
#  'a',
#  'woman',
#  'who',
#  'held',
#  'a',
#  'babe\nagainst',
#  ...]

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # Your code here:
    if x.find('\n') != -1:
        return x.split('\n')
    else:
        return x
line_break('the\nbeloved')
# Out:
# ['the', 'beloved']

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:
prophet_line = list(map(line_break,prophet_reference))
prophet_line
# Out:
# ['dispense',
#  'with',
#  ['confidence?', '', 'If'],
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  ['what', 'fields'],
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  ['in', 'what'],
#  'unremembered',
#  ['seasons?', '', 'If'],
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  ['I', 'lift'],
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  ['flame', 'that'],
#  'shall',
#  'burn',
#  ['therein.', '', 'Empty'],
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  ['lantern,', '', 'And'],
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  ['fill', 'it'],
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  ['also.', '', '*****', '', 'These'],
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  ['much', 'in'],
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  ['he', 'himself'],
#  'could',
#  'not',
#  'speak',
#  'his',
#  ['deeper', 'secret.', '', '*****', '', '[Illustration:'],
#  ['0020]', '', 'And'],
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  ['all', 'the'],
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  ['they', 'were'],
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  ['one', 'voice.', '', 'And'],
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  ['forth', 'and'],
#  ['said:', '', 'Go'],
#  'not',
#  'yet',
#  'away',
#  'from',
#  ['us.', '', 'A'],
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  ['our', 'twilight,'],
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  ['us', 'dreams'],
#  'to',
#  ['dream.', '', 'No'],
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  ['nor', 'a'],
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  ['dearly', 'beloved.', '', 'Suffer'],
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  ['for', 'your'],
#  ['face.', '', '*****', '', 'And'],
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  ['said', 'unto'],
#  ['him:', '', 'Let'],
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  ['us', 'now,'],
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  ['our', 'midst'],
#  'become',
#  'a',
#  ['memory.', '', 'You'],
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  ['spirit,', 'and'],
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  ['light', 'upon'],
#  'our',
#  ['faces.', '', 'Much'],
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  ['speechless', 'was'],
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  ['been', 'veiled.', '', 'Yet'],
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  ['and', 'would'],
#  'stand',
#  'revealed',
#  'before',
#  ['you.', '', 'And'],
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  ['knows', 'not'],
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  ['of', 'separation.', '', '*****', '', 'And'],
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  ['him.', 'But'],
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  ['bent', 'his'],
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  ['saw', 'his'],
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  ['breast.', '', 'And'],
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  ['towards', 'the'],
#  'great',
#  'square',
#  'before',
#  'the',
#  ['temple.', '', 'And'],
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  ['a', 'woman'],
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  ['she', 'was'],
#  'a',
#  ['seeress.', '', 'And'],
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  ['exceeding', 'tenderness,'],
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  ['first', 'sought'],
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  ['had', 'been'],
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  ['And', 'she'],
#  'hailed',
#  'him,',
#  ['saying:', '', 'Prophet'],
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  ['the', 'uttermost,'],
#  'long',
#  'have',
#  'you',
#  'searched',
#  ['the', 'distances'],
#  'for',
#  'your',
#  ['ship.', '', 'And'],
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  ['must', 'needs'],
#  ['go.', '', 'Deep'],
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  ['of', 'your'],
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  ['place', 'of'],
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  ['love', 'would'],
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  ['hold', 'you.', '', 'Yet'],
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  ['that', 'you'],
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  ['your', 'truth.', '', 'And'],
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  ['children,', 'and'],
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  ['it', 'shall'],
#  'not',
#  ['perish.', '', 'In'],
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  ['with', 'our'],
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  ['you', 'have'],
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  ['the', 'laughter'],
#  'of',
#  'our',
#  ['sleep.', '', 'Now'],
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  ['ourselves,', 'and'],
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  ['shown', 'you'],
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  ['and', 'death.', '', '*****', '', 'And'],
#  'he',
#  ['answered,', '', 'People'],
#  'of',
#  'Orphalese,',
#  'of',
#  'what',
#  'can',
#  ['I', 'speak'],
#  'save',
#  'of',
#  'that',
#  'which',
#  'is',
#  'even',
#  ['now', 'moving'],
#  'within',
#  'your',
#  ['souls?', '', '*****'],
#  ['*****', '', 'Then'],
#  'said',
#  'Almitra,',
#  'Speak',
#  'to',
#  'us',
#  ['of', '_Love_.', '', 'And'],
#  'he',
#  'raised',
#  'his',
#  'head',
#  'and',
#  'looked',
#  ['upon', 'the'],
#  'people,',
#  'and',
#  'there',
#  'fell',
#  'a',
#  ['stillness', 'upon'],
#  'them.',
#  'And',
#  'with',
#  'a',
#  'great',
#  'voice',
#  ['he', 'said:', '', 'When'],
#  'love',
#  'beckons',
#  'to',
#  'you,',
#  'follow',
#  ['him,', '', 'Though'],
#  'his',
#  'ways',
#  'are',
#  'hard',
#  'and',
#  ['steep.', '', 'And'],
#  'when',
#  'his',
#  'wings',
#  'enfold',
#  'you',
#  'yield',
#  ['to', 'him,', '', 'Though'],
#  'the',
#  'sword',
#  'hidden',
#  'among',
#  ['his', 'pinions'],
#  'may',
#  'wound',
#  ['you.', '', 'And'],
#  'when',
#  'he',
#  'speaks',
#  'to',
#  'you',
#  'believe',
#  ['in', 'him,', '', 'Though'],
#  'his',
#  'voice',
#  'may',
#  'shatter',
#  'your',
#  ['dreams', 'as'],
#  'the',
#  'north',
#  'wind',
#  'lays',
#  'waste',
#  'the',
#  ['garden.', '', 'For'],
#  'even',
#  'as',
#  'love',
#  'crowns',
#  'you',
#  'so',
#  ['shall', 'he'],
#  'crucify',
#  'you.',
#  'Even',
#  'as',
#  'he',
#  'is',
#  'for',
#  ['your', 'growth'],
#  'so',
#  'is',
#  'he',
#  'for',
#  'your',
#  ['pruning.', '', 'Even'],
#  'as',
#  'he',
#  'ascends',
#  'to',
#  'your',
#  'height',
#  ['and', 'caresses'],
#  'your',
#  'tenderest',
#  ['branches', 'that'],
#  'quiver',
#  'in',
#  'the',
#  ['sun,', '', 'So'],
#  'shall',
#  'he',
#  'descend',
#  'to',
#  'your',
#  'roots',
#  ['and', 'shake'],
#  'them',
#  'in',
#  'their',
#  'clinging',
#  'to',
#  ['the', 'earth.', '', '*****', '', 'Like'],
#  'sheaves',
#  'of',
#  'corn',
#  'he',
#  'gathers',
#  'you',
#  ['unto', 'himself.', '', 'He'],
#  'threshes',
#  'you',
#  'to',
#  'make',
#  'you',
#  ['naked.', '', 'He'],
#  'sifts',
#  'you',
#  'to',
#  'free',
#  'you',
#  'from',
#  ['your', 'husks.', '', 'He'],
#  'grinds',
#  'you',
#  'to',
#  ['whiteness.', '', 'He'],
#  'kneads',
#  'you',
#  'until',
#  'you',
#  'are',
#  ['pliant;', '', 'And'],
#  'then',
#  'he',
#  'assigns',
#  'you',
#  'to',
#  'his',
#  ['sacred', 'fire,'],
#  'that',
#  'you',
#  'may',
#  'become',
#  'sacred',
#  ['bread', 'for'],
#  'God’s',
#  'sacred',
#  ['feast.', '', '*****', '', 'All'],
#  'these',
#  'things',
#  'shall',
#  'love',
#  'do',
#  'unto',
#  ['you', 'that'],
#  'you',
#  'may',
#  'know',
#  'the',
#  'secrets',
#  'of',
#  ['your', 'heart,'],
#  'and',
#  'in',
#  'that',
#  'knowledge',
#  'become',
#  ['a', 'fragment'],
#  'of',
#  'Life’s',
#  ['heart.', '', 'But'],
#  'if',
#  'in',
#  'your',
#  'fear',
#  'you',
#  'would',
#  'seek',
#  ['only', 'love’s'],
#  'peace',
#  'and',
#  'love’s',
#  ['pleasure,', '', 'Then'],
#  'it',
#  'is',
#  'better',
#  'for',
#  'you',
#  'that',
#  ['you', 'cover'],
#  'your',
#  'nakedness',
#  'and',
#  'pass',
#  'out',
#  ['of', 'love’s'],
#  ['threshing-floor,', '', 'Into'],
#  'the',
#  'seasonless',
#  'world',
#  'where',
#  ['you', 'shall'],
#  'laugh,',
#  'but',
#  'not',
#  'all',
#  'of',
#  ['your', 'laughter,'],
#  'and',
#  'weep,',
#  'but',
#  'not',
#  'all',
#  'of',
#  ['your', 'tears.', '', '*****', '', 'Love'],
#  'gives',
#  'naught',
#  'but',
#  'itself',
#  'and',
#  ['takes', 'naught'],
#  'but',
#  'from',
#  ['itself.', '', 'Love'],
#  'possesses',
#  'not',
#  'nor',
#  'would',
#  'it',
#  ['be', 'possessed;', '', 'For'],
#  'love',
#  'is',
#  'sufficient',
#  'unto',
#  ['love.', '', 'When'],
#  'you',
#  'love',
#  'you',
#  'should',
#  'not',
#  'say,',
#  ['“God', 'is'],
#  'in',
#  'my',
#  'heart,”',
#  'but',
#  'rather,',
#  '“I',
#  'am',
#  ['in', 'the'],
#  'heart',
#  'of',
#  ['God.”', '', 'And'],
#  'think',
#  'not',
#  'you',
#  'can',
#  'direct',
#  'the',
#  ['course', 'of'],
#  'love,',
#  'for',
#  'love,',
#  'if',
#  'it',
#  'finds',
#  ['you', 'worthy,'],
#  'directs',
#  'your',
#  ['course.', '', 'Love'],
#  'has',
#  'no',
#  'other',
#  'desire',
#  'but',
#  'to',
#  ['fulfil', 'itself.', '', 'But'],
#  'if',
#  'you',
#  'love',
#  'and',
#  'must',
#  'needs',
#  ['have', 'desires,'],
#  'let',
#  'these',
#  'be',
#  'your',
#  ['desires:', '', 'To'],
#  'melt',
#  'and',
#  'be',
#  'like',
#  'a',
#  'running',
#  'brook',
#  ['that', 'sings'],
#  'its',
#  'melody',
#  'to',
#  'the',
#  'night.',
#  ['To', 'know'],
#  'the',
#  'pain',
#  'of',
#  'too',
#  'much',
#  ['tenderness.', '', 'To'],
#  'be',
#  'wounded',
#  'by',
#  'your',
#  'own',
#  ['understanding', 'of'],
#  ['love;', '', 'And'],
#  'to',
#  'bleed',
#  'willingly',
#  'and',
#  ['joyfully.', '', 'To'],
#  'wake',
#  'at',
#  'dawn',
#  'with',
#  'a',
#  'winged',
#  'heart',
#  ['and', 'give'],
#  'thanks',
#  'for',
#  'another',
#  'day',
#  'of',
#  ['loving;', '', 'To'],
#  'rest',
#  'at',
#  'the',
#  'noon',
#  'hour',
#  'and',
#  ['meditate', 'love’s'],
#  ['ecstacy;', '', 'To'],
#  'return',
#  'home',
#  'at',
#  'eventide',
#  ['with', 'gratitude;', '', 'And'],
#  'then',
#  'to',
#  'sleep',
#  'with',
#  'a',
#  'prayer',
#  ['for', 'the'],
#  'beloved',
#  'in',
#  'your',
#  'heart',
#  'and',
#  'a',
#  'song',
#  ['of', 'praise'],
#  'upon',
#  'your',
#  ['lips.', '', '[Illustration:'],
#  ['0029]', '', '*****'],
#  ['*****', '', 'Then'],
#  'Almitra',
#  'spoke',
#  'again',
#  'and',
#  ['said,', 'And'],
#  'what',
#  'of',
#  '_Marriage_',
#  ['master?', '', 'And'],
#  'he',
#  'answered',
#  ['saying:', '', 'You'],
#  'were',
#  'born',
#  'together,',
#  'and',
#  'together',
#  ['you', 'shall'],
#  'be',
#  ['forevermore.', '', 'You'],
#  'shall',
#  'be',
#  'together',
#  'when',
#  'the',
#  ['white', 'wings'],
#  'of',
#  'death',
#  'scatter',
#  'your',
#  ['days.', '', 'Aye,'],
#  'you',
#  'shall',
#  'be',
#  'together',
#  'even',
#  'in',
#  ['the', 'silent'],
#  'memory',
#  'of',
#  ['God.', '', 'But'],
#  'let',
#  'there',
#  'be',
#  'spaces',
#  'in',
#  ['your', 'togetherness,', '', 'And'],
#  'let',
#  'the',
#  'winds',
#  'of',
#  'the',
#  'heavens',
#  ['dance', 'between'],
#  ['you.', '', '*****', '', 'Love'],
#  'one',
#  'another,',
#  'but',
#  'make',
#  'not',
#  'a',
#  'bond',
#  ['of', 'love:', '', 'Let'],
#  'it',
#  'rather',
#  'be',
#  'a',
#  'moving',
#  'sea',
#  ['between', 'the'],
#  'shores',
#  'of',
#  'your',
#  ['souls.', '', 'Fill'],
#  'each',
#  'other’s',
#  'cup',
#  'but',
#  'drink',
#  'not',
#  ['from', 'one'],
#  ['cup.', '', 'Give'],
#  'one',
#  'another',
#  'of',
#  'your',
#  'bread',
#  'but',
#  ['eat', 'not'],
#  'from',
#  'the',
#  'same',
#  'loaf.',
#  'Sing',
#  ['and', 'dance'],
#  'together',
#  'and',
#  'be',
#  'joyous,',
#  'but',
#  ['let', 'each'],
#  'one',
#  'of',
#  'you',
#  'be',
#  ['alone,', '', 'Even'],
#  'as',
#  'the',
#  'strings',
#  'of',
#  'a',
#  'lute',
#  'are',
#  ['alone', 'though'],
#  'they',
#  'quiver',
#  'with',
#  'the',
#  'same',
#  ['music.', '', '*****', '', 'Give'],
#  'your',
#  'hearts,',
#  'but',
#  'not',
#  'into',
#  ['each', 'other’s'],
#  ['keeping.', '', 'For'],
#  'only',
#  'the',
#  'hand',
#  'of',
#  'Life',
#  'can',
#  ['contain', 'your'],
#  ['hearts.', '', 'And'],
#  'stand',
#  'together',
#  'yet',
#  'not',
#  'too',
#  ['near', 'together:', '', 'For'],
#  'the',
#  'pillars',
#  'of',
#  'the',
#  'temple',
#  ['stand', 'apart,', '', 'And'],
#  'the',
#  'oak',
#  'tree',
#  'and',
#  'the',
#  'cypress',
#  ['grow', 'not'],
#  'in',
#  'each',
#  'other’s',
#  ['shadow.', '', '[Illustration:'],
#  ['0032]', '', '*****'],
#  ['*****', '', 'And'],
#  'a',
#  'woman',
#  'who',
#  'held',
#  'a',
#  ['babe', 'against'],
#  ...]

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:
prophet_flat = [item for sublist in prophet_line for item in sublist if type(sublist) == list]

prophet_flat
# Out:
# ['confidence?',
#  '',
#  'If',
#  'what',
#  'fields',
#  'in',
#  'what',
#  'seasons?',
#  '',
#  'If',
#  'I',
#  'lift',
#  'flame',
#  'that',
#  'therein.',
#  '',
#  'Empty',
#  'lantern,',
#  '',
#  'And',
#  'fill',
#  'it',
#  'also.',
#  '',
#  '*****',
#  '',
#  'These',
#  'much',
#  'in',
#  'he',
#  'himself',
#  'deeper',
#  'secret.',
#  '',
#  '*****',
#  '',
#  '[Illustration:',
#  '0020]',
#  '',
#  'And',
#  'all',
#  'the',
#  'they',
#  'were',
#  'one',
#  'voice.',
#  '',
#  'And',
#  'forth',
#  'and',
#  'said:',
#  '',
#  'Go',
#  'us.',
#  '',
#  'A',
#  'our',
#  'twilight,',
#  'us',
#  'dreams',
#  'dream.',
#  '',
#  'No',
#  'nor',
#  'a',
#  'dearly',
#  'beloved.',
#  '',
#  'Suffer',
#  'for',
#  'your',
#  'face.',
#  '',
#  '*****',
#  '',
#  'And',
#  'said',
#  'unto',
#  'him:',
#  '',
#  'Let',
#  'us',
#  'now,',
#  'our',
#  'midst',
#  'memory.',
#  '',
#  'You',
#  'spirit,',
#  'and',
#  'light',
#  'upon',
#  'faces.',
#  '',
#  'Much',
#  'speechless',
#  'was',
#  'been',
#  'veiled.',
#  '',
#  'Yet',
#  'and',
#  'would',
#  'you.',
#  '',
#  'And',
#  'knows',
#  'not',
#  'of',
#  'separation.',
#  '',
#  '*****',
#  '',
#  'And',
#  'him.',
#  'But',
#  'bent',
#  'his',
#  'saw',
#  'his',
#  'breast.',
#  '',
#  'And',
#  'towards',
#  'the',
#  'temple.',
#  '',
#  'And',
#  'a',
#  'woman',
#  'she',
#  'was',
#  'seeress.',
#  '',
#  'And',
#  'exceeding',
#  'tenderness,',
#  'first',
#  'sought',
#  'had',
#  'been',
#  'And',
#  'she',
#  'saying:',
#  '',
#  'Prophet',
#  'the',
#  'uttermost,',
#  'the',
#  'distances',
#  'ship.',
#  '',
#  'And',
#  'must',
#  'needs',
#  'go.',
#  '',
#  'Deep',
#  'of',
#  'your',
#  'place',
#  'of',
#  'love',
#  'would',
#  'hold',
#  'you.',
#  '',
#  'Yet',
#  'that',
#  'you',
#  'your',
#  'truth.',
#  '',
#  'And',
#  'children,',
#  'and',
#  'it',
#  'shall',
#  'perish.',
#  '',
#  'In',
#  'with',
#  'our',
#  'you',
#  'have',
#  'the',
#  'laughter',
#  'sleep.',
#  '',
#  'Now',
#  'ourselves,',
#  'and',
#  'shown',
#  'you',
#  'and',
#  'death.',
#  '',
#  '*****',
#  '',
#  'And',
#  'answered,',
#  '',
#  'People',
#  'I',
#  'speak',
#  'now',
#  'moving',
#  'souls?',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Love_.',
#  '',
#  'And',
#  'upon',
#  'the',
#  'stillness',
#  'upon',
#  'he',
#  'said:',
#  '',
#  'When',
#  'him,',
#  '',
#  'Though',
#  'steep.',
#  '',
#  'And',
#  'to',
#  'him,',
#  '',
#  'Though',
#  'his',
#  'pinions',
#  'you.',
#  '',
#  'And',
#  'in',
#  'him,',
#  '',
#  'Though',
#  'dreams',
#  'as',
#  'garden.',
#  '',
#  'For',
#  'shall',
#  'he',
#  'your',
#  'growth',
#  'pruning.',
#  '',
#  'Even',
#  'and',
#  'caresses',
#  'branches',
#  'that',
#  'sun,',
#  '',
#  'So',
#  'and',
#  'shake',
#  'the',
#  'earth.',
#  '',
#  '*****',
#  '',
#  'Like',
#  'unto',
#  'himself.',
#  '',
#  'He',
#  'naked.',
#  '',
#  'He',
#  'your',
#  'husks.',
#  '',
#  'He',
#  'whiteness.',
#  '',
#  'He',
#  'pliant;',
#  '',
#  'And',
#  'sacred',
#  'fire,',
#  'bread',
#  'for',
#  'feast.',
#  '',
#  '*****',
#  '',
#  'All',
#  'you',
#  'that',
#  'your',
#  'heart,',
#  'a',
#  'fragment',
#  'heart.',
#  '',
#  'But',
#  'only',
#  'love’s',
#  'pleasure,',
#  '',
#  'Then',
#  'you',
#  'cover',
#  'of',
#  'love’s',
#  'threshing-floor,',
#  '',
#  'Into',
#  'you',
#  'shall',
#  'your',
#  'laughter,',
#  'your',
#  'tears.',
#  '',
#  '*****',
#  '',
#  'Love',
#  'takes',
#  'naught',
#  'itself.',
#  '',
#  'Love',
#  'be',
#  'possessed;',
#  '',
#  'For',
#  'love.',
#  '',
#  'When',
#  '“God',
#  'is',
#  'in',
#  'the',
#  'God.”',
#  '',
#  'And',
#  'course',
#  'of',
#  'you',
#  'worthy,',
#  'course.',
#  '',
#  'Love',
#  'fulfil',
#  'itself.',
#  '',
#  'But',
#  'have',
#  'desires,',
#  'desires:',
#  '',
#  'To',
#  'that',
#  'sings',
#  'To',
#  'know',
#  'tenderness.',
#  '',
#  'To',
#  'understanding',
#  'of',
#  'love;',
#  '',
#  'And',
#  'joyfully.',
#  '',
#  'To',
#  'and',
#  'give',
#  'loving;',
#  '',
#  'To',
#  'meditate',
#  'love’s',
#  'ecstacy;',
#  '',
#  'To',
#  'with',
#  'gratitude;',
#  '',
#  'And',
#  'for',
#  'the',
#  'of',
#  'praise',
#  'lips.',
#  '',
#  '[Illustration:',
#  '0029]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'said,',
#  'And',
#  'master?',
#  '',
#  'And',
#  'saying:',
#  '',
#  'You',
#  'you',
#  'shall',
#  'forevermore.',
#  '',
#  'You',
#  'white',
#  'wings',
#  'days.',
#  '',
#  'Aye,',
#  'the',
#  'silent',
#  'God.',
#  '',
#  'But',
#  'your',
#  'togetherness,',
#  '',
#  'And',
#  'dance',
#  'between',
#  'you.',
#  '',
#  '*****',
#  '',
#  'Love',
#  'of',
#  'love:',
#  '',
#  'Let',
#  'between',
#  'the',
#  'souls.',
#  '',
#  'Fill',
#  'from',
#  'one',
#  'cup.',
#  '',
#  'Give',
#  'eat',
#  'not',
#  'and',
#  'dance',
#  'let',
#  'each',
#  'alone,',
#  '',
#  'Even',
#  'alone',
#  'though',
#  'music.',
#  '',
#  '*****',
#  '',
#  'Give',
#  'each',
#  'other’s',
#  'keeping.',
#  '',
#  'For',
#  'contain',
#  'your',
#  'hearts.',
#  '',
#  'And',
#  'near',
#  'together:',
#  '',
#  'For',
#  'stand',
#  'apart,',
#  '',
#  'And',
#  'grow',
#  'not',
#  'shadow.',
#  '',
#  '[Illustration:',
#  '0032]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'And',
#  'babe',
#  'against',
#  'of',
#  '_Children_.',
#  '',
#  'And',
#  'said:',
#  '',
#  'Your',
#  'children.',
#  '',
#  'They',
#  'of',
#  'Life’s',
#  'itself.',
#  '',
#  'They',
#  'you,',
#  '',
#  'And',
#  'they',
#  'belong',
#  'you.',
#  '',
#  '*****',
#  '',
#  'You',
#  'your',
#  'thoughts,',
#  '',
#  'For',
#  'thoughts.',
#  '',
#  'You',
#  'their',
#  'souls,',
#  '',
#  'For',
#  'of',
#  'tomorrow,',
#  'not',
#  'even',
#  'dreams.',
#  '',
#  'You',
#  'seek',
#  'not',
#  'For',
#  'life',
#  'with',
#  'yesterday.',
#  '',
#  'You',
#  'your',
#  'children',
#  'sent',
#  'forth.',
#  '',
#  'The',
#  'path',
#  'of',
#  'with',
#  'His',
#  'swift',
#  'and',
#  'far.',
#  '',
#  'Let',
#  'be',
#  'for',
#  'gladness;',
#  '',
#  'For',
#  'that',
#  'flies,',
#  'is',
#  'stable.',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Giving_.',
#  '',
#  'And',
#  'answered:',
#  '',
#  'You',
#  'of',
#  'your',
#  'possessions.',
#  '',
#  'It',
#  'you',
#  'truly',
#  'give.',
#  '',
#  'For',
#  'things',
#  'you',
#  'need',
#  'them',
#  'tomorrow?',
#  '',
#  'And',
#  'bring',
#  'to',
#  'bones',
#  'in',
#  'the',
#  'pilgrims',
#  'city?',
#  '',
#  'And',
#  'need',
#  'itself?',
#  '',
#  'Is',
#  'is',
#  'full,',
#  'unquenchable?',
#  '',
#  'There',
#  'the',
#  'much',
#  'give',
#  'it',
#  'hidden',
#  'desire',
#  'unwholesome.',
#  '',
#  'And',
#  'and',
#  'give',
#  'all.',
#  '',
#  'These',
#  'and',
#  'the',
#  'is',
#  'never',
#  'empty.',
#  '',
#  'There',
#  'and',
#  'that',
#  'reward.',
#  '',
#  'And',
#  'pain,',
#  'and',
#  'baptism.',
#  '',
#  'And',
#  'know',
#  'not',
#  'seek',
#  'joy,',
#  'of',
#  'virtue;',
#  '',
#  'They',
#  'myrtle',
#  'breathes',
#  'space.',
#  '',
#  'Through',
#  'God',
#  'speaks,',
#  'He',
#  'smiles',
#  'earth.',
#  '',
#  '[Illustration:',
#  '0039]',
#  '',
#  'It',
#  'it',
#  'is',
#  'through',
#  'understanding;',
#  '',
#  'And',
#  'for',
#  'one',
#  'greater',
#  'than',
#  'giving.',
#  '',
#  'And',
#  'withhold?',
#  '',
#  'All',
#  'given;',
#  '',
#  'Therefore',
#  'season',
#  'of',
#  'your',
#  'inheritors’.',
#  '',
#  'You',
#  'only',
#  'to',
#  'deserving.”',
#  '',
#  'The',
#  'so,',
#  'nor',
#  'pasture.',
#  '',
#  'They',
#  'to',
#  'withhold',
#  'perish.',
#  '',
#  'Surely',
#  'his',
#  'days',
#  'all',
#  'else',
#  'you.',
#  '',
#  'And',
#  'from',
#  'the',
#  'his',
#  'cup',
#  'stream.',
#  '',
#  'And',
#  'be,',
#  'than',
#  'courage',
#  'and',
#  'of',
#  'receiving?',
#  '',
#  'And',
#  'rend',
#  'their',
#  'pride,',
#  'that',
#  'and',
#  'their',
#  'unabashed?',
#  '',
#  'See',
#  'to',
#  'be',
#  'giving.',
#  '',
#  'For',
#  'unto',
#  'life--while',
#  'a',
#  'giver,',
#  'witness.',
#  '',
#  'And',
#  'are',
#  'all',
#  'of',
#  'gratitude,',
#  'upon',
#  'yourself',
#  'gives.',
#  '',
#  'Rather',
#  'on',
#  'his',
#  'wings;',
#  '',
#  'For',
#  'is',
#  'ito',
#  'the',
#  'freehearted',
#  'God',
#  'for',
#  'father.',
#  '',
#  '[Illustration:',
#  '0042]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'an',
#  'inn,',
#  'and',
#  'Drinking_.',
#  '',
#  'And',
#  'said:',
#  '',
#  'Would',
#  'the',
#  'fragrance',
#  'air',
#  'plant',
#  'light.',
#  '',
#  'But',
#  'rob',
#  'the',
#  'to',
#  'quench',
#  'an',
#  'act',
#  'worship,',
#  '',
#  'And',
#  'on',
#  'which',
#  'of',
#  'forest',
#  'that',
#  'which',
#  'innocent',
#  'in',
#  'man.',
#  '',
#  '*****',
#  '',
#  'When',
#  'your',
#  'heart,',
#  '',
#  '“By',
#  'too',
#  'am',
#  'consumed.',
#  'For',
#  'into',
#  'my',
#  'mightier',
#  'hand.',
#  '',
#  'Your',
#  'but',
#  'the',
#  'heaven.”',
#  '',
#  '*****',
#  '',
#  'And',
#  'your',
#  'teeth,',
#  'heart,',
#  '',
#  '“Your',
#  'body,',
#  '',
#  'And',
#  'shall',
#  'blossom',
#  'heart,',
#  '',
#  'And',
#  'breath,',
#  'And',
#  'through',
#  'all',
#  'seasons.”',
#  '',
#  '*****',
#  '',
#  'And',
#  'gather',
#  'the',
#  'the',
#  'winepress,',
#  'heart,',
#  '',
#  '“I',
#  'shall',
#  'be',
#  'winepress,',
#  '',
#  'And',
#  'in',
#  'eternal',
#  'vessels.”',
#  '',
#  'And',
#  'wine,',
#  'let',
#  'song',
#  'for',
#  'cup;',
#  '',
#  'And',
#  'a',
#  'remembrance',
#  'for',
#  'the',
#  'winepress.',
#  '',
#  '*****',
#  '*****',
#  '',
#  '',
#  'Speak',
#  'to',
#  '_Work_.',
#  '',
#  'And',
#  'saying:',
#  '',
#  'You',
#  'the',
#  'earth',
#  'earth.',
#  '',
#  'For',
#  'stranger',
#  'unto',
#  'of',
#  'life’s',
#  'in',
#  'majesty',
#  'the',
#  'infinite.',
#  '',
#  'When',
#  'through',
#  'whose',
#  'hours',
#  'turns',
#  'music.',
#  '',
#  'Which',
#  'and',
#  'silent,',
#  'in',
#  'unison?',
#  '',
#  'Always',
#  'a',
#  'curse',
#  'misfortune.',
#  '',
#  'But',
#  'you',
#  'fulfil',
#  'dream,',
#  'assigned',
#  'was',
#  'born,',
#  '',
#  'And',
#  'you',
#  'are',
#  'life,',
#  '',
#  'And',
#  'be',
#  'intimate',
#  'secret.',
#  '',
#  '*****',
#  '',
#  'But',
#  'an',
#  'affliction',
#  'flesh',
#  'a',
#  'I',
#  'answer',
#  'of',
#  'your',
#  'is',
#  'written.',
#  '',
#  'You',
#  'is',
#  'darkness,',
#  'echo',
#  'what',
#  'weary.',
#  '',
#  'And',
#  'darkness',
#  '‘save',
#  'urge,',
#  '',
#  'And',
#  'is',
#  'knowledge,',
#  '',
#  'And',
#  'when',
#  'there',
#  'work,',
#  '',
#  'And',
#  'is',
#  'love;',
#  '',
#  ...]

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: true if the word is not in the specified list and false if the word is in the list
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:
    if x not in word_list:
        return True
    else: 
        return False
    
prophet_filter = list(filter(word_filter,prophet_flat))  
prophet_filter
# Out:
# ['confidence?',
#  '',
#  'If',
#  'what',
#  'fields',
#  'in',
#  'what',
#  'seasons?',
#  '',
#  'If',
#  'I',
#  'lift',
#  'flame',
#  'that',
#  'therein.',
#  '',
#  'Empty',
#  'lantern,',
#  '',
#  'And',
#  'fill',
#  'it',
#  'also.',
#  '',
#  '*****',
#  '',
#  'These',
#  'much',
#  'in',
#  'he',
#  'himself',
#  'deeper',
#  'secret.',
#  '',
#  '*****',
#  '',
#  '[Illustration:',
#  '0020]',
#  '',
#  'And',
#  'all',
#  'they',
#  'were',
#  'one',
#  'voice.',
#  '',
#  'And',
#  'forth',
#  'said:',
#  '',
#  'Go',
#  'us.',
#  '',
#  'A',
#  'our',
#  'twilight,',
#  'us',
#  'dreams',
#  'dream.',
#  '',
#  'No',
#  'nor',
#  'dearly',
#  'beloved.',
#  '',
#  'Suffer',
#  'for',
#  'your',
#  'face.',
#  '',
#  '*****',
#  '',
#  'And',
#  'said',
#  'unto',
#  'him:',
#  '',
#  'Let',
#  'us',
#  'now,',
#  'our',
#  'midst',
#  'memory.',
#  '',
#  'You',
#  'spirit,',
#  'light',
#  'upon',
#  'faces.',
#  '',
#  'Much',
#  'speechless',
#  'was',
#  'been',
#  'veiled.',
#  '',
#  'Yet',
#  'would',
#  'you.',
#  '',
#  'And',
#  'knows',
#  'not',
#  'of',
#  'separation.',
#  '',
#  '*****',
#  '',
#  'And',
#  'him.',
#  'But',
#  'bent',
#  'his',
#  'saw',
#  'his',
#  'breast.',
#  '',
#  'And',
#  'towards',
#  'temple.',
#  '',
#  'And',
#  'woman',
#  'she',
#  'was',
#  'seeress.',
#  '',
#  'And',
#  'exceeding',
#  'tenderness,',
#  'first',
#  'sought',
#  'had',
#  'been',
#  'And',
#  'she',
#  'saying:',
#  '',
#  'Prophet',
#  'uttermost,',
#  'distances',
#  'ship.',
#  '',
#  'And',
#  'must',
#  'needs',
#  'go.',
#  '',
#  'Deep',
#  'of',
#  'your',
#  'place',
#  'of',
#  'love',
#  'would',
#  'hold',
#  'you.',
#  '',
#  'Yet',
#  'that',
#  'you',
#  'your',
#  'truth.',
#  '',
#  'And',
#  'children,',
#  'it',
#  'shall',
#  'perish.',
#  '',
#  'In',
#  'with',
#  'our',
#  'you',
#  'have',
#  'laughter',
#  'sleep.',
#  '',
#  'Now',
#  'ourselves,',
#  'shown',
#  'you',
#  'death.',
#  '',
#  '*****',
#  '',
#  'And',
#  'answered,',
#  '',
#  'People',
#  'I',
#  'speak',
#  'now',
#  'moving',
#  'souls?',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Love_.',
#  '',
#  'And',
#  'upon',
#  'stillness',
#  'upon',
#  'he',
#  'said:',
#  '',
#  'When',
#  'him,',
#  '',
#  'Though',
#  'steep.',
#  '',
#  'And',
#  'to',
#  'him,',
#  '',
#  'Though',
#  'his',
#  'pinions',
#  'you.',
#  '',
#  'And',
#  'in',
#  'him,',
#  '',
#  'Though',
#  'dreams',
#  'as',
#  'garden.',
#  '',
#  'For',
#  'shall',
#  'he',
#  'your',
#  'growth',
#  'pruning.',
#  '',
#  'Even',
#  'caresses',
#  'branches',
#  'that',
#  'sun,',
#  '',
#  'So',
#  'shake',
#  'earth.',
#  '',
#  '*****',
#  '',
#  'Like',
#  'unto',
#  'himself.',
#  '',
#  'He',
#  'naked.',
#  '',
#  'He',
#  'your',
#  'husks.',
#  '',
#  'He',
#  'whiteness.',
#  '',
#  'He',
#  'pliant;',
#  '',
#  'And',
#  'sacred',
#  'fire,',
#  'bread',
#  'for',
#  'feast.',
#  '',
#  '*****',
#  '',
#  'All',
#  'you',
#  'that',
#  'your',
#  'heart,',
#  'fragment',
#  'heart.',
#  '',
#  'But',
#  'only',
#  'love’s',
#  'pleasure,',
#  '',
#  'Then',
#  'you',
#  'cover',
#  'of',
#  'love’s',
#  'threshing-floor,',
#  '',
#  'Into',
#  'you',
#  'shall',
#  'your',
#  'laughter,',
#  'your',
#  'tears.',
#  '',
#  '*****',
#  '',
#  'Love',
#  'takes',
#  'naught',
#  'itself.',
#  '',
#  'Love',
#  'be',
#  'possessed;',
#  '',
#  'For',
#  'love.',
#  '',
#  'When',
#  '“God',
#  'is',
#  'in',
#  'God.”',
#  '',
#  'And',
#  'course',
#  'of',
#  'you',
#  'worthy,',
#  'course.',
#  '',
#  'Love',
#  'fulfil',
#  'itself.',
#  '',
#  'But',
#  'have',
#  'desires,',
#  'desires:',
#  '',
#  'To',
#  'that',
#  'sings',
#  'To',
#  'know',
#  'tenderness.',
#  '',
#  'To',
#  'understanding',
#  'of',
#  'love;',
#  '',
#  'And',
#  'joyfully.',
#  '',
#  'To',
#  'give',
#  'loving;',
#  '',
#  'To',
#  'meditate',
#  'love’s',
#  'ecstacy;',
#  '',
#  'To',
#  'with',
#  'gratitude;',
#  '',
#  'And',
#  'for',
#  'of',
#  'praise',
#  'lips.',
#  '',
#  '[Illustration:',
#  '0029]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'said,',
#  'And',
#  'master?',
#  '',
#  'And',
#  'saying:',
#  '',
#  'You',
#  'you',
#  'shall',
#  'forevermore.',
#  '',
#  'You',
#  'white',
#  'wings',
#  'days.',
#  '',
#  'Aye,',
#  'silent',
#  'God.',
#  '',
#  'But',
#  'your',
#  'togetherness,',
#  '',
#  'And',
#  'dance',
#  'between',
#  'you.',
#  '',
#  '*****',
#  '',
#  'Love',
#  'of',
#  'love:',
#  '',
#  'Let',
#  'between',
#  'souls.',
#  '',
#  'Fill',
#  'from',
#  'one',
#  'cup.',
#  '',
#  'Give',
#  'eat',
#  'not',
#  'dance',
#  'let',
#  'each',
#  'alone,',
#  '',
#  'Even',
#  'alone',
#  'though',
#  'music.',
#  '',
#  '*****',
#  '',
#  'Give',
#  'each',
#  'other’s',
#  'keeping.',
#  '',
#  'For',
#  'contain',
#  'your',
#  'hearts.',
#  '',
#  'And',
#  'near',
#  'together:',
#  '',
#  'For',
#  'stand',
#  'apart,',
#  '',
#  'And',
#  'grow',
#  'not',
#  'shadow.',
#  '',
#  '[Illustration:',
#  '0032]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'And',
#  'babe',
#  'against',
#  'of',
#  '_Children_.',
#  '',
#  'And',
#  'said:',
#  '',
#  'Your',
#  'children.',
#  '',
#  'They',
#  'of',
#  'Life’s',
#  'itself.',
#  '',
#  'They',
#  'you,',
#  '',
#  'And',
#  'they',
#  'belong',
#  'you.',
#  '',
#  '*****',
#  '',
#  'You',
#  'your',
#  'thoughts,',
#  '',
#  'For',
#  'thoughts.',
#  '',
#  'You',
#  'their',
#  'souls,',
#  '',
#  'For',
#  'of',
#  'tomorrow,',
#  'not',
#  'even',
#  'dreams.',
#  '',
#  'You',
#  'seek',
#  'not',
#  'For',
#  'life',
#  'with',
#  'yesterday.',
#  '',
#  'You',
#  'your',
#  'children',
#  'sent',
#  'forth.',
#  '',
#  'The',
#  'path',
#  'of',
#  'with',
#  'His',
#  'swift',
#  'far.',
#  '',
#  'Let',
#  'be',
#  'for',
#  'gladness;',
#  '',
#  'For',
#  'that',
#  'flies,',
#  'is',
#  'stable.',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Giving_.',
#  '',
#  'And',
#  'answered:',
#  '',
#  'You',
#  'of',
#  'your',
#  'possessions.',
#  '',
#  'It',
#  'you',
#  'truly',
#  'give.',
#  '',
#  'For',
#  'things',
#  'you',
#  'need',
#  'them',
#  'tomorrow?',
#  '',
#  'And',
#  'bring',
#  'to',
#  'bones',
#  'in',
#  'pilgrims',
#  'city?',
#  '',
#  'And',
#  'need',
#  'itself?',
#  '',
#  'Is',
#  'is',
#  'full,',
#  'unquenchable?',
#  '',
#  'There',
#  'much',
#  'give',
#  'it',
#  'hidden',
#  'desire',
#  'unwholesome.',
#  '',
#  'And',
#  'give',
#  'all.',
#  '',
#  'These',
#  'is',
#  'never',
#  'empty.',
#  '',
#  'There',
#  'that',
#  'reward.',
#  '',
#  'And',
#  'pain,',
#  'baptism.',
#  '',
#  'And',
#  'know',
#  'not',
#  'seek',
#  'joy,',
#  'of',
#  'virtue;',
#  '',
#  'They',
#  'myrtle',
#  'breathes',
#  'space.',
#  '',
#  'Through',
#  'God',
#  'speaks,',
#  'He',
#  'smiles',
#  'earth.',
#  '',
#  '[Illustration:',
#  '0039]',
#  '',
#  'It',
#  'it',
#  'is',
#  'through',
#  'understanding;',
#  '',
#  'And',
#  'for',
#  'one',
#  'greater',
#  'than',
#  'giving.',
#  '',
#  'And',
#  'withhold?',
#  '',
#  'All',
#  'given;',
#  '',
#  'Therefore',
#  'season',
#  'of',
#  'your',
#  'inheritors’.',
#  '',
#  'You',
#  'only',
#  'to',
#  'deserving.”',
#  '',
#  'The',
#  'so,',
#  'nor',
#  'pasture.',
#  '',
#  'They',
#  'to',
#  'withhold',
#  'perish.',
#  '',
#  'Surely',
#  'his',
#  'days',
#  'all',
#  'else',
#  'you.',
#  '',
#  'And',
#  'from',
#  'his',
#  'cup',
#  'stream.',
#  '',
#  'And',
#  'be,',
#  'than',
#  'courage',
#  'of',
#  'receiving?',
#  '',
#  'And',
#  'rend',
#  'their',
#  'pride,',
#  'that',
#  'their',
#  'unabashed?',
#  '',
#  'See',
#  'to',
#  'be',
#  'giving.',
#  '',
#  'For',
#  'unto',
#  'life--while',
#  'giver,',
#  'witness.',
#  '',
#  'And',
#  'are',
#  'all',
#  'of',
#  'gratitude,',
#  'upon',
#  'yourself',
#  'gives.',
#  '',
#  'Rather',
#  'on',
#  'his',
#  'wings;',
#  '',
#  'For',
#  'is',
#  'ito',
#  'freehearted',
#  'God',
#  'for',
#  'father.',
#  '',
#  '[Illustration:',
#  '0042]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'inn,',
#  'Drinking_.',
#  '',
#  'And',
#  'said:',
#  '',
#  'Would',
#  'fragrance',
#  'air',
#  'plant',
#  'light.',
#  '',
#  'But',
#  'rob',
#  'to',
#  'quench',
#  'act',
#  'worship,',
#  '',
#  'And',
#  'on',
#  'which',
#  'of',
#  'forest',
#  'that',
#  'which',
#  'innocent',
#  'in',
#  'man.',
#  '',
#  '*****',
#  '',
#  'When',
#  'your',
#  'heart,',
#  '',
#  '“By',
#  'too',
#  'am',
#  'consumed.',
#  'For',
#  'into',
#  'my',
#  'mightier',
#  'hand.',
#  '',
#  'Your',
#  'but',
#  'heaven.”',
#  '',
#  '*****',
#  '',
#  'And',
#  'your',
#  'teeth,',
#  'heart,',
#  '',
#  '“Your',
#  'body,',
#  '',
#  'And',
#  'shall',
#  'blossom',
#  'heart,',
#  '',
#  'And',
#  'breath,',
#  'And',
#  'through',
#  'all',
#  'seasons.”',
#  '',
#  '*****',
#  '',
#  'And',
#  'gather',
#  'winepress,',
#  'heart,',
#  '',
#  '“I',
#  'shall',
#  'be',
#  'winepress,',
#  '',
#  'And',
#  'in',
#  'eternal',
#  'vessels.”',
#  '',
#  'And',
#  'wine,',
#  'let',
#  'song',
#  'for',
#  'cup;',
#  '',
#  'And',
#  'remembrance',
#  'for',
#  'winepress.',
#  '',
#  '*****',
#  '*****',
#  '',
#  '',
#  'Speak',
#  'to',
#  '_Work_.',
#  '',
#  'And',
#  'saying:',
#  '',
#  'You',
#  'earth',
#  'earth.',
#  '',
#  'For',
#  'stranger',
#  'unto',
#  'of',
#  'life’s',
#  'in',
#  'majesty',
#  'infinite.',
#  '',
#  'When',
#  'through',
#  'whose',
#  'hours',
#  'turns',
#  'music.',
#  '',
#  'Which',
#  'silent,',
#  'in',
#  'unison?',
#  '',
#  'Always',
#  'curse',
#  'misfortune.',
#  '',
#  'But',
#  'you',
#  'fulfil',
#  'dream,',
#  'assigned',
#  'was',
#  'born,',
#  '',
#  'And',
#  'you',
#  'are',
#  'life,',
#  '',
#  'And',
#  'be',
#  'intimate',
#  'secret.',
#  '',
#  '*****',
#  '',
#  'But',
#  'affliction',
#  'flesh',
#  'I',
#  'answer',
#  'of',
#  'your',
#  'is',
#  'written.',
#  '',
#  'You',
#  'is',
#  'darkness,',
#  'echo',
#  'what',
#  'weary.',
#  '',
#  'And',
#  'darkness',
#  '‘save',
#  'urge,',
#  '',
#  'And',
#  'is',
#  'knowledge,',
#  '',
#  'And',
#  'when',
#  'there',
#  'work,',
#  '',
#  'And',
#  'is',
#  'love;',
#  '',
#  'And',
#  'bind',
#  'yourself',
#  'one',
#  'another,',
#  'God.',
#  '',
#  '*****',
#  '',
#  'And',
#  'love?',
#  '',
#  'It',
#  'threads',
#  'drawn',
#  'your',
#  'beloved',
#  'cloth.',
#  '',
#  'It',
#  'affection,',
#  'even',
#  'in',
#  'that',
#  'house.',
#  '',
#  'It',
#  'reap',
#  'if',
#  'your',
#  'fruit.',
#  '',
#  'It',
#  'fashion',
#  'with',
#  'spirit,',
#  '',
#  'And',
#  'dead',
#  'are',
#  'watching.',
#  '',
#  'Often',
#  'if',
#  'speaking',
#  'in',
#  'marble,',
#  'own',
#  'soul',
#  'who',
#  'ploughs',
#  'seizes',
#  'likeness',
#  ...]

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:    
    
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:
    if x.lower() not in word_list:
        return True
    else: 
        return False
prophet_filter2 = list(filter(word_filter_case,prophet_flat))  
prophet_filter2
# Out:
# ['confidence?',
#  '',
#  'If',
#  'what',
#  'fields',
#  'in',
#  'what',
#  'seasons?',
#  '',
#  'If',
#  'I',
#  'lift',
#  'flame',
#  'that',
#  'therein.',
#  '',
#  'Empty',
#  'lantern,',
#  '',
#  'fill',
#  'it',
#  'also.',
#  '',
#  '*****',
#  '',
#  'These',
#  'much',
#  'in',
#  'he',
#  'himself',
#  'deeper',
#  'secret.',
#  '',
#  '*****',
#  '',
#  '[Illustration:',
#  '0020]',
#  '',
#  'all',
#  'they',
#  'were',
#  'one',
#  'voice.',
#  '',
#  'forth',
#  'said:',
#  '',
#  'Go',
#  'us.',
#  '',
#  'our',
#  'twilight,',
#  'us',
#  'dreams',
#  'dream.',
#  '',
#  'No',
#  'nor',
#  'dearly',
#  'beloved.',
#  '',
#  'Suffer',
#  'for',
#  'your',
#  'face.',
#  '',
#  '*****',
#  '',
#  'said',
#  'unto',
#  'him:',
#  '',
#  'Let',
#  'us',
#  'now,',
#  'our',
#  'midst',
#  'memory.',
#  '',
#  'You',
#  'spirit,',
#  'light',
#  'upon',
#  'faces.',
#  '',
#  'Much',
#  'speechless',
#  'was',
#  'been',
#  'veiled.',
#  '',
#  'Yet',
#  'would',
#  'you.',
#  '',
#  'knows',
#  'not',
#  'of',
#  'separation.',
#  '',
#  '*****',
#  '',
#  'him.',
#  'But',
#  'bent',
#  'his',
#  'saw',
#  'his',
#  'breast.',
#  '',
#  'towards',
#  'temple.',
#  '',
#  'woman',
#  'she',
#  'was',
#  'seeress.',
#  '',
#  'exceeding',
#  'tenderness,',
#  'first',
#  'sought',
#  'had',
#  'been',
#  'she',
#  'saying:',
#  '',
#  'Prophet',
#  'uttermost,',
#  'distances',
#  'ship.',
#  '',
#  'must',
#  'needs',
#  'go.',
#  '',
#  'Deep',
#  'of',
#  'your',
#  'place',
#  'of',
#  'love',
#  'would',
#  'hold',
#  'you.',
#  '',
#  'Yet',
#  'that',
#  'you',
#  'your',
#  'truth.',
#  '',
#  'children,',
#  'it',
#  'shall',
#  'perish.',
#  '',
#  'In',
#  'with',
#  'our',
#  'you',
#  'have',
#  'laughter',
#  'sleep.',
#  '',
#  'Now',
#  'ourselves,',
#  'shown',
#  'you',
#  'death.',
#  '',
#  '*****',
#  '',
#  'answered,',
#  '',
#  'People',
#  'I',
#  'speak',
#  'now',
#  'moving',
#  'souls?',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Love_.',
#  '',
#  'upon',
#  'stillness',
#  'upon',
#  'he',
#  'said:',
#  '',
#  'When',
#  'him,',
#  '',
#  'Though',
#  'steep.',
#  '',
#  'to',
#  'him,',
#  '',
#  'Though',
#  'his',
#  'pinions',
#  'you.',
#  '',
#  'in',
#  'him,',
#  '',
#  'Though',
#  'dreams',
#  'as',
#  'garden.',
#  '',
#  'For',
#  'shall',
#  'he',
#  'your',
#  'growth',
#  'pruning.',
#  '',
#  'Even',
#  'caresses',
#  'branches',
#  'that',
#  'sun,',
#  '',
#  'So',
#  'shake',
#  'earth.',
#  '',
#  '*****',
#  '',
#  'Like',
#  'unto',
#  'himself.',
#  '',
#  'He',
#  'naked.',
#  '',
#  'He',
#  'your',
#  'husks.',
#  '',
#  'He',
#  'whiteness.',
#  '',
#  'He',
#  'pliant;',
#  '',
#  'sacred',
#  'fire,',
#  'bread',
#  'for',
#  'feast.',
#  '',
#  '*****',
#  '',
#  'All',
#  'you',
#  'that',
#  'your',
#  'heart,',
#  'fragment',
#  'heart.',
#  '',
#  'But',
#  'only',
#  'love’s',
#  'pleasure,',
#  '',
#  'Then',
#  'you',
#  'cover',
#  'of',
#  'love’s',
#  'threshing-floor,',
#  '',
#  'Into',
#  'you',
#  'shall',
#  'your',
#  'laughter,',
#  'your',
#  'tears.',
#  '',
#  '*****',
#  '',
#  'Love',
#  'takes',
#  'naught',
#  'itself.',
#  '',
#  'Love',
#  'be',
#  'possessed;',
#  '',
#  'For',
#  'love.',
#  '',
#  'When',
#  '“God',
#  'is',
#  'in',
#  'God.”',
#  '',
#  'course',
#  'of',
#  'you',
#  'worthy,',
#  'course.',
#  '',
#  'Love',
#  'fulfil',
#  'itself.',
#  '',
#  'But',
#  'have',
#  'desires,',
#  'desires:',
#  '',
#  'To',
#  'that',
#  'sings',
#  'To',
#  'know',
#  'tenderness.',
#  '',
#  'To',
#  'understanding',
#  'of',
#  'love;',
#  '',
#  'joyfully.',
#  '',
#  'To',
#  'give',
#  'loving;',
#  '',
#  'To',
#  'meditate',
#  'love’s',
#  'ecstacy;',
#  '',
#  'To',
#  'with',
#  'gratitude;',
#  '',
#  'for',
#  'of',
#  'praise',
#  'lips.',
#  '',
#  '[Illustration:',
#  '0029]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'said,',
#  'master?',
#  '',
#  'saying:',
#  '',
#  'You',
#  'you',
#  'shall',
#  'forevermore.',
#  '',
#  'You',
#  'white',
#  'wings',
#  'days.',
#  '',
#  'Aye,',
#  'silent',
#  'God.',
#  '',
#  'But',
#  'your',
#  'togetherness,',
#  '',
#  'dance',
#  'between',
#  'you.',
#  '',
#  '*****',
#  '',
#  'Love',
#  'of',
#  'love:',
#  '',
#  'Let',
#  'between',
#  'souls.',
#  '',
#  'Fill',
#  'from',
#  'one',
#  'cup.',
#  '',
#  'Give',
#  'eat',
#  'not',
#  'dance',
#  'let',
#  'each',
#  'alone,',
#  '',
#  'Even',
#  'alone',
#  'though',
#  'music.',
#  '',
#  '*****',
#  '',
#  'Give',
#  'each',
#  'other’s',
#  'keeping.',
#  '',
#  'For',
#  'contain',
#  'your',
#  'hearts.',
#  '',
#  'near',
#  'together:',
#  '',
#  'For',
#  'stand',
#  'apart,',
#  '',
#  'grow',
#  'not',
#  'shadow.',
#  '',
#  '[Illustration:',
#  '0032]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'babe',
#  'against',
#  'of',
#  '_Children_.',
#  '',
#  'said:',
#  '',
#  'Your',
#  'children.',
#  '',
#  'They',
#  'of',
#  'Life’s',
#  'itself.',
#  '',
#  'They',
#  'you,',
#  '',
#  'they',
#  'belong',
#  'you.',
#  '',
#  '*****',
#  '',
#  'You',
#  'your',
#  'thoughts,',
#  '',
#  'For',
#  'thoughts.',
#  '',
#  'You',
#  'their',
#  'souls,',
#  '',
#  'For',
#  'of',
#  'tomorrow,',
#  'not',
#  'even',
#  'dreams.',
#  '',
#  'You',
#  'seek',
#  'not',
#  'For',
#  'life',
#  'with',
#  'yesterday.',
#  '',
#  'You',
#  'your',
#  'children',
#  'sent',
#  'forth.',
#  '',
#  'path',
#  'of',
#  'with',
#  'His',
#  'swift',
#  'far.',
#  '',
#  'Let',
#  'be',
#  'for',
#  'gladness;',
#  '',
#  'For',
#  'that',
#  'flies,',
#  'is',
#  'stable.',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Giving_.',
#  '',
#  'answered:',
#  '',
#  'You',
#  'of',
#  'your',
#  'possessions.',
#  '',
#  'It',
#  'you',
#  'truly',
#  'give.',
#  '',
#  'For',
#  'things',
#  'you',
#  'need',
#  'them',
#  'tomorrow?',
#  '',
#  'bring',
#  'to',
#  'bones',
#  'in',
#  'pilgrims',
#  'city?',
#  '',
#  'need',
#  'itself?',
#  '',
#  'Is',
#  'is',
#  'full,',
#  'unquenchable?',
#  '',
#  'There',
#  'much',
#  'give',
#  'it',
#  'hidden',
#  'desire',
#  'unwholesome.',
#  '',
#  'give',
#  'all.',
#  '',
#  'These',
#  'is',
#  'never',
#  'empty.',
#  '',
#  'There',
#  'that',
#  'reward.',
#  '',
#  'pain,',
#  'baptism.',
#  '',
#  'know',
#  'not',
#  'seek',
#  'joy,',
#  'of',
#  'virtue;',
#  '',
#  'They',
#  'myrtle',
#  'breathes',
#  'space.',
#  '',
#  'Through',
#  'God',
#  'speaks,',
#  'He',
#  'smiles',
#  'earth.',
#  '',
#  '[Illustration:',
#  '0039]',
#  '',
#  'It',
#  'it',
#  'is',
#  'through',
#  'understanding;',
#  '',
#  'for',
#  'one',
#  'greater',
#  'than',
#  'giving.',
#  '',
#  'withhold?',
#  '',
#  'All',
#  'given;',
#  '',
#  'Therefore',
#  'season',
#  'of',
#  'your',
#  'inheritors’.',
#  '',
#  'You',
#  'only',
#  'to',
#  'deserving.”',
#  '',
#  'so,',
#  'nor',
#  'pasture.',
#  '',
#  'They',
#  'to',
#  'withhold',
#  'perish.',
#  '',
#  'Surely',
#  'his',
#  'days',
#  'all',
#  'else',
#  'you.',
#  '',
#  'from',
#  'his',
#  'cup',
#  'stream.',
#  '',
#  'be,',
#  'than',
#  'courage',
#  'of',
#  'receiving?',
#  '',
#  'rend',
#  'their',
#  'pride,',
#  'that',
#  'their',
#  'unabashed?',
#  '',
#  'See',
#  'to',
#  'be',
#  'giving.',
#  '',
#  'For',
#  'unto',
#  'life--while',
#  'giver,',
#  'witness.',
#  '',
#  'are',
#  'all',
#  'of',
#  'gratitude,',
#  'upon',
#  'yourself',
#  'gives.',
#  '',
#  'Rather',
#  'on',
#  'his',
#  'wings;',
#  '',
#  'For',
#  'is',
#  'ito',
#  'freehearted',
#  'God',
#  'for',
#  'father.',
#  '',
#  '[Illustration:',
#  '0042]',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'inn,',
#  'Drinking_.',
#  '',
#  'said:',
#  '',
#  'Would',
#  'fragrance',
#  'air',
#  'plant',
#  'light.',
#  '',
#  'But',
#  'rob',
#  'to',
#  'quench',
#  'act',
#  'worship,',
#  '',
#  'on',
#  'which',
#  'of',
#  'forest',
#  'that',
#  'which',
#  'innocent',
#  'in',
#  'man.',
#  '',
#  '*****',
#  '',
#  'When',
#  'your',
#  'heart,',
#  '',
#  '“By',
#  'too',
#  'am',
#  'consumed.',
#  'For',
#  'into',
#  'my',
#  'mightier',
#  'hand.',
#  '',
#  'Your',
#  'but',
#  'heaven.”',
#  '',
#  '*****',
#  '',
#  'your',
#  'teeth,',
#  'heart,',
#  '',
#  '“Your',
#  'body,',
#  '',
#  'shall',
#  'blossom',
#  'heart,',
#  '',
#  'breath,',
#  'through',
#  'all',
#  'seasons.”',
#  '',
#  '*****',
#  '',
#  'gather',
#  'winepress,',
#  'heart,',
#  '',
#  '“I',
#  'shall',
#  'be',
#  'winepress,',
#  '',
#  'in',
#  'eternal',
#  'vessels.”',
#  '',
#  'wine,',
#  'let',
#  'song',
#  'for',
#  'cup;',
#  '',
#  'remembrance',
#  'for',
#  'winepress.',
#  '',
#  '*****',
#  '*****',
#  '',
#  '',
#  'Speak',
#  'to',
#  '_Work_.',
#  '',
#  'saying:',
#  '',
#  'You',
#  'earth',
#  'earth.',
#  '',
#  'For',
#  'stranger',
#  'unto',
#  'of',
#  'life’s',
#  'in',
#  'majesty',
#  'infinite.',
#  '',
#  'When',
#  'through',
#  'whose',
#  'hours',
#  'turns',
#  'music.',
#  '',
#  'Which',
#  'silent,',
#  'in',
#  'unison?',
#  '',
#  'Always',
#  'curse',
#  'misfortune.',
#  '',
#  'But',
#  'you',
#  'fulfil',
#  'dream,',
#  'assigned',
#  'was',
#  'born,',
#  '',
#  'you',
#  'are',
#  'life,',
#  '',
#  'be',
#  'intimate',
#  'secret.',
#  '',
#  '*****',
#  '',
#  'But',
#  'affliction',
#  'flesh',
#  'I',
#  'answer',
#  'of',
#  'your',
#  'is',
#  'written.',
#  '',
#  'You',
#  'is',
#  'darkness,',
#  'echo',
#  'what',
#  'weary.',
#  '',
#  'darkness',
#  '‘save',
#  'urge,',
#  '',
#  'is',
#  'knowledge,',
#  '',
#  'when',
#  'there',
#  'work,',
#  '',
#  'is',
#  'love;',
#  '',
#  'bind',
#  'yourself',
#  'one',
#  'another,',
#  'God.',
#  '',
#  '*****',
#  '',
#  'love?',
#  '',
#  'It',
#  'threads',
#  'drawn',
#  'your',
#  'beloved',
#  'cloth.',
#  '',
#  'It',
#  'affection,',
#  'even',
#  'in',
#  'that',
#  'house.',
#  '',
#  'It',
#  'reap',
#  'if',
#  'your',
#  'fruit.',
#  '',
#  'It',
#  'fashion',
#  'with',
#  'spirit,',
#  '',
#  'dead',
#  'are',
#  'watching.',
#  '',
#  'Often',
#  'if',
#  'speaking',
#  'in',
#  'marble,',
#  'own',
#  'soul',
#  'who',
#  'ploughs',
#  'seizes',
#  'likeness',
#  'who',
#  'makes',
#  'feet.”',
#  '',
#  'But',
#  'overwakefulness',
#  'wind',
#  'giant',
#  'blades',
#  'grass;',
#  '',
#  'voice',
#  'made',
#  'sweeter',
#  'loving.',
#  '',
#  '*****',
#  '',
#  'Work',
#  'visible.',
#  '',
#  'but',
#  'only',
#  'that',
#  'you',
#  'at',
#  'of',
#  'those',
#  'joy.',
#  '',
#  'For',
#  'indifference,',
#  'you',
#  'but',
#  'half',
#  'hunger.',
#  '',
#  'grapes,',
#  'in',
#  'as',
#  'angels,',
#  'you',
#  'muffle',
#  'day',
#  'night.',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'of',
#  '_Joy',
#  'Sorrow_.',
#  '',
#  'answered:',
#  '',
#  'Your',
#  'unmasked.',
#  '',
#  'your',
#  'laughter',
#  'filled',
#  'with',
#  ...]

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # Your code here:
    return f'{a} {b}'
# Out:
# 'Jon Snow'

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# Your code here:
prophet_string = reduce(concat_space, prophet_filter)
prophet_string
# Out:
# 'confidence?  If what fields in what seasons?  If I lift flame that therein.  Empty lantern,  fill it also.  *****  These much in he himself deeper secret.  *****  [Illustration: 0020]  all they were one voice.  forth said:  Go us.  our twilight, us dreams dream.  No nor dearly beloved.  Suffer for your face.  *****  said unto him:  Let us now, our midst memory.  You spirit, light upon faces.  Much speechless was been veiled.  Yet would you.  knows not of separation.  *****  him. But bent his saw his breast.  towards temple.  woman she was seeress.  exceeding tenderness, first sought had been she saying:  Prophet uttermost, distances ship.  must needs go.  Deep of your place of love would hold you.  Yet that you your truth.  children, it shall perish.  In with our you have laughter sleep.  Now ourselves, shown you death.  *****  answered,  People I speak now moving souls?  ***** *****  Then of _Love_.  upon stillness upon he said:  When him,  Though steep.  to him,  Though his pinions you.  in him,  Though dreams as garden.  For shall he your growth pruning.  Even caresses branches that sun,  So shake earth.  *****  Like unto himself.  He naked.  He your husks.  He whiteness.  He pliant;  sacred fire, bread for feast.  *****  All you that your heart, fragment heart.  But only love’s pleasure,  Then you cover of love’s threshing-floor,  Into you shall your laughter, your tears.  *****  Love takes naught itself.  Love be possessed;  For love.  When “God is in God.”  course of you worthy, course.  Love fulfil itself.  But have desires, desires:  To that sings To know tenderness.  To understanding of love;  joyfully.  To give loving;  To meditate love’s ecstacy;  To with gratitude;  for of praise lips.  [Illustration: 0029]  ***** *****  Then said, master?  saying:  You you shall forevermore.  You white wings days.  Aye, silent God.  But your togetherness,  dance between you.  *****  Love of love:  Let between souls.  Fill from one cup.  Give eat not dance let each alone,  Even alone though music.  *****  Give each other’s keeping.  For contain your hearts.  near together:  For stand apart,  grow not shadow.  [Illustration: 0032]  ***** *****  babe against of _Children_.  said:  Your children.  They of Life’s itself.  They you,  they belong you.  *****  You your thoughts,  For thoughts.  You their souls,  For of tomorrow, not even dreams.  You seek not For life with yesterday.  You your children sent forth.  path of with His swift far.  Let be for gladness;  For that flies, is stable.  ***** *****  Then of _Giving_.  answered:  You of your possessions.  It you truly give.  For things you need them tomorrow?  bring to bones in pilgrims city?  need itself?  Is is full, unquenchable?  There much give it hidden desire unwholesome.  give all.  These is never empty.  There that reward.  pain, baptism.  know not seek joy, of virtue;  They myrtle breathes space.  Through God speaks, He smiles earth.  [Illustration: 0039]  It it is through understanding;  for one greater than giving.  withhold?  All given;  Therefore season of your inheritors’.  You only to deserving.”  so, nor pasture.  They to withhold perish.  Surely his days all else you.  from his cup stream.  be, than courage of receiving?  rend their pride, that their unabashed?  See to be giving.  For unto life--while giver, witness.  are all of gratitude, upon yourself gives.  Rather on his wings;  For is ito freehearted God for father.  [Illustration: 0042]  ***** *****  Then inn, Drinking_.  said:  Would fragrance air plant light.  But rob to quench act worship,  on which of forest that which innocent in man.  *****  When your heart,  “By too am consumed. For into my mightier hand.  Your but heaven.”  *****  your teeth, heart,  “Your body,  shall blossom heart,  breath, through all seasons.”  *****  gather winepress, heart,  “I shall be winepress,  in eternal vessels.”  wine, let song for cup;  remembrance for winepress.  ***** *****   Speak to _Work_.  saying:  You earth earth. ...
